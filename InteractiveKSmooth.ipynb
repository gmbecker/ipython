# %%
# %load_ext rmagic

# %% [markdown]
# In this document we use a simplified example to illustrate how *interactivecodecells* can be used to give the reader the ability to interactively explore and verify the robustness of a statistical analysis to tuning parameter values.

# %% [markdown]
# Below we have an *interactivecodecell* which fits a kernel estimator to the **cars** dataset included with R. Unlike traditional dynamic documents, however, interactivecodecells allow viewers to control the parameters used in the "analysis" and thus expore the robustness of the results themselves.

# %% [raw]
# %%R
# bw = 35;
# dat = cars
# plot(speed~dist, data = dat)
# lines(ksmooth(dat$dist, dat$speed, "normal", bandwidth=bw), col="green")

# %% [raw]
# Tada!
